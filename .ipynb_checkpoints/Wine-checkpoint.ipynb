# %%
import os
import tarfile
from six.moves import urllib

DOWNLOAD_ROOT = "https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/"
WINE_PATH = os.path.join("datasets","wine")
RED_WINE_URL = DOWNLOAD_ROOT + "winequality-red.csv"

def fetch_wine_data(wine_url=RED_WINE_URL, wine_path=WINE_PATH):
    if not os.path.isdir(wine_path):
        os.makedirs(wine_path)
    tgz_path = os.path.join(wine_path, "winequality-red.csv")
    urllib.request.urlretrieve(red_wine_url, tgz_path)
    housing_tgz = tarfile.open(tgz_path)
    housing_tgz.extractall(path=housing_path)
    housing_tgz.close()

# %%
import pandas as pd

def load_wine_data(filepath=RED_WINE_URL):
#     csv_path = os.path.join(filepath, "housing.csv")
    csv_path = filepath
    return pd.read_csv(csv_path, sep=";")

# %%
red_wine = load_wine_data()
red_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
red_wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
# fixed acidity           1599 non-null float64
# volatile acidity        1599 non-null float64
# citric acid             1599 non-null float64
# residual sugar          1599 non-null float64
# chlorides               1599 non-null float64
# free sulfur dioxide     1599 non-null float64
# total sulfur dioxide    1599 non-null float64
# density                 1599 non-null float64
# pH                      1599 non-null float64
# sulphates               1599 non-null float64
# alcohol                 1599 non-null float64
# quality                 1599 non-null int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
red_wine.hist(bins=50, figsize=(20,15))
plt.show()

# %%
import numpy as np

def split_train_test(data, test_ratio):
    shuffled_indices = np.random.permutation(len(data))
    test_set_size = int(len(data) * test_ratio)
    test_indices = shuffled_indices[:test_set_size]
    train_indices = shuffled_indices[test_set_size:]
    return data.iloc[train_indices], data.iloc[test_indices]

# %%
train_set, test_set = split_train_test(red_wine, 0.2)
print(len(train_set), ", ", len(test_set))
# Out:
# 1280 ,  319

# %%
from sklearn.model_selection import train_test_split

train_set, test_set = train_test_split(red_wine, test_size=0.2, random_state=42)

# %%
train_set, test_set = split_train_test(red_wine, 0.2)
print(len(train_set), ",", len(test_set))
# Out:
# 1280 , 319

# %%
red_wine["density_cat"] = np.ceil(red_wine["density"] * 1000 / 1.5)
# red_wine["density_cat"].where(red_wine["density_cat"] < 5, 5.0, inplace=True)

# %%
from sklearn.model_selection import StratifiedShuffleSplit

split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
for train_index, test_index in split.split(red_wine, red_wine["density_cat"]):
    strat_train_set = red_wine.loc[train_index]
    strat_test_set = red_wine.loc[test_index]

# %%
strat_test_set["density_cat"].value_counts() / len(strat_test_set)
# Out:
# 5.0    1.0
# Name: density_cat, dtype: float64
